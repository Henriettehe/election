# %% [markdown]
# Step 1: importing required libraries

# %%
# importing required libraries 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter("ignore")
pd.set_option('display.max_columns', None)

# %% [markdown]
# # importing required libraries
#
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# from sklearn.model_selection import train_test_split
# import warnings
# warnings.simplefilter("ignore")
# pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importing the Data

# %%
result_df = pd.read_csv('./dataset/results.csv')
stats_df = pd.read_csv('./dataset/status.csv')
drivers_df = pd.read_csv('./dataset/drivers.csv')
races_df = pd.read_csv('./dataset/races.csv')
constructor_df = pd.read_csv('./dataset/constructors.csv')
driver_standings_df = pd.read_csv('./dataset/driver_standings.csv')
pd.get_option("display.max_columns",None)

# %%
result_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
result_df.tail()
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 26075     26081    1110       817            213      3    19       16
# 26076     26082    1110       858              3      2    18       17
# 26077     26083    1110       807            210     27     0       18
# 26078     26084    1110       832              6     55     4       \N
# 26079     26085    1110       857              1     81     5       \N
#
#       positionText  positionOrder  points  laps       time milliseconds  \
# 26075           16             16     0.0    44  +1:43.071      5053521
# 26076           17             17     0.0    44  +1:44.476      5054926
# 26077           18             18     0.0    44  +1:50.450      5060900
# 26078            R             19     0.0    23         \N           \N
# 26079            R             20     0.0     0         \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 26075         25   15       1:50.994         227.169         1
# 26076         37    9       1:50.486         228.213         1
# 26077         26    4       1:49.907         229.415         1
# 26078          9   19       1:53.138         222.864       130
# 26079         \N    0             \N              \N       130

# %%
stats_df.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
stats_df.tail()
# Out:
#      statusId          status
# 134       137          Damage
# 135       138          Debris
# 136       139         Illness
# 137       140       Undertray
# 138       141  Cooling system

# %%
drivers_df.head(10)
# Out:
#    driverId   driverRef number code   forename     surname         dob  \
# 0         1    hamilton     44  HAM      Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI       Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS       Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO   Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV     Heikki  Kovalainen  1981-10-19
# 5         6    nakajima     \N  NAK     Kazuki    Nakajima  1985-01-11
# 6         7    bourdais     \N  BOU  Sébastien    Bourdais  1979-02-28
# 7         8   raikkonen      7  RAI       Kimi   Räikkönen  1979-10-17
# 8         9      kubica     88  KUB     Robert      Kubica  1984-12-07
# 9        10       glock     \N  GLO       Timo       Glock  1982-03-18
#
#   nationality                                                url
# 0     British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German         http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German          http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish       http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish     http://en.wikipedia.org/wiki/Heikki_Kovalainen
# 5    Japanese       http://en.wikipedia.org/wiki/Kazuki_Nakajima
# 6      French  http://en.wikipedia.org/wiki/S%C3%A9bastien_Bo...
# 7     Finnish  http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C...
# 8      Polish         http://en.wikipedia.org/wiki/Robert_Kubica
# 9      German            http://en.wikipedia.org/wiki/Timo_Glock

# %%
drivers_df.tail()
# Out:
#      driverId        driverRef number code forename     surname         dob  \
# 852       854  mick_schumacher     47  MSC     Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO   Guanyu        Zhou  1999-05-30
# 854       856         de_vries     21  DEV     Nyck    de Vries  1995-02-06
# 855       857          piastri     81  PIA    Oscar     Piastri  2001-04-06
# 856       858         sargeant      2  SAR    Logan    Sargeant  2000-12-31
#
#     nationality                                           url
# 852      German  http://en.wikipedia.org/wiki/Mick_Schumacher
# 853     Chinese      http://en.wikipedia.org/wiki/Zhou_Guanyu
# 854       Dutch    http://en.wikipedia.org/wiki/Nyck_de_Vries
# 855  Australian    http://en.wikipedia.org/wiki/Oscar_Piastri
# 856    American   http://en.wikipedia.org/wiki/Logan_Sargeant

# %%
races_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# 0       \N       \N       \N       \N       \N         \N         \N
# 1       \N       \N       \N       \N       \N         \N         \N
# 2       \N       \N       \N       \N       \N         \N         \N
# 3       \N       \N       \N       \N       \N         \N         \N
# 4       \N       \N       \N       \N       \N         \N         \N
#
#   sprint_date sprint_time
# 0          \N          \N
# 1          \N          \N
# 2          \N          \N
# 3          \N          \N
# 4          \N          \N

# %%
races_df.tail()
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 1096    1116  2023     18         69  United States Grand Prix  2023-10-22
# 1097    1117  2023     19         32    Mexico City Grand Prix  2023-10-29
# 1098    1118  2023     20         18      São Paulo Grand Prix  2023-11-05
# 1099    1119  2023     21         80      Las Vegas Grand Prix  2023-11-19
# 1100    1120  2023     22         24      Abu Dhabi Grand Prix  2023-11-26
#
#           time                                                url    fp1_date  \
# 1096  19:00:00  https://en.wikipedia.org/wiki/2023_United_Stat...  2023-10-20
# 1097  20:00:00  https://en.wikipedia.org/wiki/2023_Mexico_City...  2023-10-27
# 1098  17:00:00  https://en.wikipedia.org/wiki/2023_S%C3%A3o_Pa...  2023-11-03
# 1099  06:00:00  https://en.wikipedia.org/wiki/2023_Las_Vegas_G...  2023-11-17
# 1100  13:00:00  https://en.wikipedia.org/wiki/2023_Abu_Dhabi_G...  2023-11-24
#
#       fp1_time    fp2_date  fp2_time    fp3_date  fp3_time  quali_date  \
# 1096  17:30:00  2023-10-21  18:00:00          \N        \N  2023-10-20
# 1097  18:30:00  2023-10-27  22:00:00  2023-10-28  17:30:00  2023-10-28
# 1098  14:30:00  2023-11-04  14:30:00          \N        \N  2023-11-03
# 1099  04:30:00  2023-11-17  08:00:00  2023-11-18  04:30:00  2023-11-18
# 1100  09:30:00  2023-11-24  13:00:00  2023-11-25  10:30:00  2023-11-25
#
#      quali_time sprint_date sprint_time
# 1096   21:00:00  2023-10-21    22:00:00
# 1097   21:00:00          \N          \N
# 1098   18:00:00  2023-11-04    18:30:00
# 1099   08:00:00          \N          \N
# 1100   14:00:00          \N          \N

# %%
constructor_df.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
constructor_df.tail()
# Out:
#      constructorId constructorRef            name nationality  \
# 206            209          manor  Manor Marussia     British
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 206      http://en.wikipedia.org/wiki/Manor_Motorsport
# 207          http://en.wikipedia.org/wiki/Haas_F1_Team
# 208  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 209   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 210        http://en.wikipedia.org/wiki/Alpine_F1_Team

# %%
driver_standings_df.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
driver_standings_df.tail()
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 34119              72183    1110       846    69.0         8            8
# 34120              72184    1110       839    35.0        10           10
# 34121              72185    1110       844    99.0         5            5
# 34122              72186    1110       857    34.0        11           11
# 34123              72187    1110       817     0.0        21           21
#
#        wins
# 34119     0
# 34120     0
# 34121     0
# 34122     0
# 34123     0

# %% [markdown]
# # Feature Engineering

# %%
races_df['raceId']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1096    1116
# 1097    1117
# 1098    1118
# 1099    1119
# 1100    1120
# Name: raceId, Length: 1101, dtype: int64

# %%
races_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   raceId       1101 non-null   int64
#  1   year         1101 non-null   int64
#  2   round        1101 non-null   int64
#  3   circuitId    1101 non-null   int64
#  4   name         1101 non-null   object
#  5   date         1101 non-null   object
#  6   time         1101 non-null   object
#  7   url          1101 non-null   object
#  8   fp1_date     1101 non-null   object
#  9   fp1_time     1101 non-null   object
#  10  fp2_date     1101 non-null   object
#  11  fp2_time     1101 non-null   object
#  12  fp3_date     1101 non-null   object
#  13  fp3_time     1101 non-null   object
#  14  quali_date   1101 non-null   object
#  15  quali_time   1101 non-null   object
#  16  sprint_date  1101 non-null   object
#  17  sprint_time  1101 non-null   object
# dtypes: int64(4), object(14)
# memory usage: 155.0+ KB

# %%
races_df.describe()
# Out:
#             raceId         year        round    circuitId
# count  1101.000000  1101.000000  1101.000000  1101.000000
# mean    553.355132  1992.020890     8.494096    23.700272
# std     321.425790    20.296406     5.081089    19.346014
# min       1.000000  1950.000000     1.000000     1.000000
# 25%     276.000000  1976.000000     4.000000     9.000000
# 50%     551.000000  1994.000000     8.000000    18.000000
# 75%     826.000000  2010.000000    12.000000    34.000000
# max    1120.000000  2023.000000    22.000000    80.000000

# %%
races_df = races_df.raceId.astype(int)

# %%
races_df
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1096    1116
# 1097    1117
# 1098    1118
# 1099    1119
# 1100    1120
# Name: raceId, Length: 1101, dtype: int32

# %%
# merging all seperate dataframe into single dataframe as df

con1 = pd.merge(result_df, races_df, on ='raceId')
con2 = pd.merge(con1, drivers_df, on = 'driverId')
con3 = pd.merge(con2, driver_standings_df, on = 'driverId')
con4 = pd.merge(con3, constructor_df, on ='constructorId')
df = pd.merge(con4, stats_df, on ='statusId')
pd.get_option("display.max_columns",None)
df.head()
# Out:
#    resultId  raceId_x  driverId  constructorId number_x  grid position_x  \
# 0         1        18         1              1       22     1          1
# 1         1        18         1              1       22     1          1
# 2         1        18         1              1       22     1          1
# 3         1        18         1              1       22     1          1
# 4         1        18         1              1       22     1          1
#
#   positionText_x  positionOrder  points_x  laps         time milliseconds  \
# 0              1              1      10.0    58  1:34:50.616      5690616
# 1              1              1      10.0    58  1:34:50.616      5690616
# 2              1              1      10.0    58  1:34:50.616      5690616
# 3              1              1      10.0    58  1:34:50.616      5690616
# 4              1              1      10.0    58  1:34:50.616      5690616
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId driverRef number_y  \
# 0         39    2       1:27.452         218.300         1  hamilton       44
# 1         39    2       1:27.452         218.300         1  hamilton       44
# 2         39    2       1:27.452         218.300         1  hamilton       44
# 3         39    2       1:27.452         218.300         1  hamilton       44
# 4         39    2       1:27.452         218.300         1  hamilton       44
#
#   code forename   surname         dob nationality_x  \
# 0  HAM    Lewis  Hamilton  1985-01-07       British
# 1  HAM    Lewis  Hamilton  1985-01-07       British
# 2  HAM    Lewis  Hamilton  1985-01-07       British
# 3  HAM    Lewis  Hamilton  1985-01-07       British
# 4  HAM    Lewis  Hamilton  1985-01-07       British
#
#                                          url_x  driverStandingsId  raceId_y  \
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton                  1        18
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton                  9        19
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton                 27        20
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton                 48        21
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton                 69        22
#
#    points_y  position_y positionText_y  wins constructorRef     name  \
# 0      10.0           1              1     1        mclaren  McLaren
# 1      14.0           1              1     1        mclaren  McLaren
# 2      14.0           3              3     1        mclaren  McLaren
# 3      20.0           2              2     1        mclaren  McLaren
# 4      28.0           3              3     1        mclaren  McLaren
#
#   nationality_y                                 url_y    status
# 0       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 1       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 2       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 3       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 4       British  http://en.wikipedia.org/wiki/McLaren  Finished

# %%
print(pd.get_option("display.max_columns"))
# Out:
# None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3537627 entries, 0 to 3537626
# Data columns (total 37 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   resultId           int64
#  1   raceId_x           int64
#  2   driverId           int64
#  3   constructorId      int64
#  4   number_x           object
#  5   grid               int64
#  6   position_x         object
#  7   positionText_x     object
#  8   positionOrder      int64
#  9   points_x           float64
#  10  laps               int64
#  11  time               object
#  12  milliseconds       object
#  13  fastestLap         object
#  14  rank               object
#  15  fastestLapTime     object
#  16  fastestLapSpeed    object
#  17  statusId           int64
#  18  driverRef          object
#  19  number_y           object
#  20  code               object
#  21  forename           object
#  22  surname            object
#  23  dob                object
#  24  nationality_x      object
#  25  url_x              object
#  26  driverStandingsId  int64
#  27  raceId_y           int64
#  28  points_y           float64
#  29  position_y         int64
#  30  positionText_y     object
#  31  wins               int64
#  32  constructorRef     object
#  33  name               object
#  34  nationality_y      object
#  35  url_y              object
#  36  status             object
# dtypes: float64(2), int64(12), object(23)
# memory usage: 1.0+ GB

# %%
# checking of null values

df.isna()
# Out:
#          resultId  raceId_x  driverId  constructorId  number_x   grid  \
# 0           False     False     False          False     False  False
# 1           False     False     False          False     False  False
# 2           False     False     False          False     False  False
# 3           False     False     False          False     False  False
# 4           False     False     False          False     False  False
# ...           ...       ...       ...            ...       ...    ...
# 3537622     False     False     False          False     False  False
# 3537623     False     False     False          False     False  False
# 3537624     False     False     False          False     False  False
# 3537625     False     False     False          False     False  False
# 3537626     False     False     False          False     False  False
#
#          position_x  positionText_x  positionOrder  points_x   laps   time  \
# 0             False           False          False     False  False  False
# 1             False           False          False     False  False  False
# 2             False           False          False     False  False  False
# 3             False           False          False     False  False  False
# 4             False           False          False     False  False  False
# ...             ...             ...            ...       ...    ...    ...
# 3537622       False           False          False     False  False  False
# 3537623       False           False          False     False  False  False
# 3537624       False           False          False     False  False  False
# 3537625       False           False          False     False  False  False
# 3537626       False           False          False     False  False  False
#
#          milliseconds  fastestLap   rank  fastestLapTime  fastestLapSpeed  \
# 0               False       False  False           False            False
# 1               False       False  False           False            False
# 2               False       False  False           False            False
# 3               False       False  False           False            False
# 4               False       False  False           False            False
# ...               ...         ...    ...             ...              ...
# 3537622         False       False  False           False            False
# 3537623         False       False  False           False            False
# 3537624         False       False  False           False            False
# 3537625         False       False  False           False            False
# 3537626         False       False  False           False            False
#
#          statusId  driverRef  number_y   code  forename  surname    dob  \
# 0           False      False     False  False     False    False  False
# 1           False      False     False  False     False    False  False
# 2           False      False     False  False     False    False  False
# 3           False      False     False  False     False    False  False
# 4           False      False     False  False     False    False  False
# ...           ...        ...       ...    ...       ...      ...    ...
# 3537622     False      False     False  False     False    False  False
# 3537623     False      False     False  False     False    False  False
# 3537624     False      False     False  False     False    False  False
# 3537625     False      False     False  False     False    False  False
# 3537626     False      False     False  False     False    False  False
#
#          nationality_x  url_x  driverStandingsId  raceId_y  points_y  \
# 0                False  False              False     False     False
# 1                False  False              False     False     False
# 2                False  False              False     False     False
# 3                False  False              False     False     False
# 4                False  False              False     False     False
# ...                ...    ...                ...       ...       ...
# 3537622          False  False              False     False     False
# 3537623          False  False              False     False     False
# 3537624          False  False              False     False     False
# 3537625          False  False              False     False     False
# 3537626          False  False              False     False     False
#
#          position_y  positionText_y   wins  constructorRef   name  \
# 0             False           False  False           False  False
# 1             False           False  False           False  False
# 2             False           False  False           False  False
# 3             False           False  False           False  False
# 4             False           False  False           False  False
# ...             ...             ...    ...             ...    ...
# 3537622       False           False  False           False  False
# 3537623       False           False  False           False  False
# 3537624       False           False  False           False  False
# 3537625       False           False  False           False  False
# 3537626       False           False  False           False  False
#
#          nationality_y  url_y  status
# 0                False  False   False
# 1                False  False   False
# 2                False  False   False
# 3                False  False   False
# 4                False  False   False
# ...                ...    ...     ...
# 3537622          False  False   False
# 3537623          False  False   False
# 3537624          False  False   False
# 3537625          False  False   False
# 3537626          False  False   False
#
# [3537627 rows x 37 columns]

# %% [markdown]
# # Note:There's no null values in the dataset

# %%
# There's no null values in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3537627 entries, 0 to 3537626
# Data columns (total 37 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   resultId           int64
#  1   raceId_x           int64
#  2   driverId           int64
#  3   constructorId      int64
#  4   number_x           object
#  5   grid               int64
#  6   position_x         object
#  7   positionText_x     object
#  8   positionOrder      int64
#  9   points_x           float64
#  10  laps               int64
#  11  time               object
#  12  milliseconds       object
#  13  fastestLap         object
#  14  rank               object
#  15  fastestLapTime     object
#  16  fastestLapSpeed    object
#  17  statusId           int64
#  18  driverRef          object
#  19  number_y           object
#  20  code               object
#  21  forename           object
#  22  surname            object
#  23  dob                object
#  24  nationality_x      object
#  25  url_x              object
#  26  driverStandingsId  int64
#  27  raceId_y           int64
#  28  points_y           float64
#  29  position_y         int64
#  30  positionText_y     object
#  31  wins               int64
#  32  constructorRef     object
#  33  name               object
#  34  nationality_y      object
#  35  url_y              object
#  36  status             object
# dtypes: float64(2), int64(12), object(23)
# memory usage: 1.0+ GB

# %% [markdown]
# # Describe
# Describe function is used to show the statistical value of each column. which all include:
#
# * Count of the column
# * Mean value of the column
# * Standard Deviation of the column
# * Minimum value of the column
# * 25% percentile of the column
# * 50% percentile of the column
# * 75% percentile of the column
# * Maximum value of the column

# %%
# summary
df.describe()
# Out:
#            resultId      raceId_x      driverId  constructorId          grid  \
# count  3.537627e+06  3.537627e+06  3.537627e+06   3.537627e+06  3.537627e+06
# mean   1.263009e+04  5.170666e+02  2.041828e+02   3.941215e+01  9.763203e+00
# std    8.209508e+03  3.315362e+02  2.658523e+02   5.686047e+01  6.557031e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00  0.000000e+00
# 25%    5.125000e+03  2.340000e+02  2.000000e+01   6.000000e+00  4.000000e+00
# 50%    1.176300e+04  4.670000e+02  1.050000e+02   1.600000e+01  9.000000e+00
# 75%    2.114000e+04  8.560000e+02  2.290000e+02   3.700000e+01  1.500000e+01
# max    2.608500e+04  1.110000e+03  8.580000e+02   2.140000e+02  3.400000e+01
#
#        positionOrder      points_x          laps      statusId  \
# count   3.537627e+06  3.537627e+06  3.537627e+06  3.537627e+06
# mean    1.122956e+01  2.998598e+00  4.836204e+01  1.323813e+01
# std     7.378775e+00  5.334331e+00  2.512323e+01  2.254451e+01
# min     1.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# 25%     5.000000e+00  0.000000e+00  3.200000e+01  1.000000e+00
# 50%     1.000000e+01  0.000000e+00  5.500000e+01  5.000000e+00
# 75%     1.700000e+01  4.000000e+00  6.700000e+01  1.200000e+01
# max     3.900000e+01  5.000000e+01  2.000000e+02  1.410000e+02
#
#        driverStandingsId      raceId_y      points_y    position_y  \
# count       3.537627e+06  3.537627e+06  3.537627e+06  3.537627e+06
# mean        4.011746e+04  5.193302e+02  2.839100e+01  1.165484e+01
# std         2.530927e+04  3.319626e+02  5.204755e+01  9.133026e+00
# min         1.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00
# 25%         1.385600e+04  2.380000e+02  1.000000e+00  5.000000e+00
# 50%         4.996000e+04  4.700000e+02  8.000000e+00  1.000000e+01
# 75%         6.582400e+04  8.570000e+02  3.100000e+01  1.600000e+01
# max         7.218700e+04  1.110000e+03  4.540000e+02  1.080000e+02
#
#                wins
# count  3.537627e+06
# mean   5.517376e-01
# std    1.452231e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.500000e+01

# %%
df.head(20)
# Out:
#     resultId  raceId_x  driverId  constructorId number_x  grid position_x  \
# 0          1        18         1              1       22     1          1
# 1          1        18         1              1       22     1          1
# 2          1        18         1              1       22     1          1
# 3          1        18         1              1       22     1          1
# 4          1        18         1              1       22     1          1
# 5          1        18         1              1       22     1          1
# 6          1        18         1              1       22     1          1
# 7          1        18         1              1       22     1          1
# 8          1        18         1              1       22     1          1
# 9          1        18         1              1       22     1          1
# 10         1        18         1              1       22     1          1
# 11         1        18         1              1       22     1          1
# 12         1        18         1              1       22     1          1
# 13         1        18         1              1       22     1          1
# 14         1        18         1              1       22     1          1
# 15         1        18         1              1       22     1          1
# 16         1        18         1              1       22     1          1
# 17         1        18         1              1       22     1          1
# 18         1        18         1              1       22     1          1
# 19         1        18         1              1       22     1          1
#
#    positionText_x  positionOrder  points_x  laps         time milliseconds  \
# 0               1              1      10.0    58  1:34:50.616      5690616
# 1               1              1      10.0    58  1:34:50.616      5690616
# 2               1              1      10.0    58  1:34:50.616      5690616
# 3               1              1      10.0    58  1:34:50.616      5690616
# 4               1              1      10.0    58  1:34:50.616      5690616
# 5               1              1      10.0    58  1:34:50.616      5690616
# 6               1              1      10.0    58  1:34:50.616      5690616
# 7               1              1      10.0    58  1:34:50.616      5690616
# 8               1              1      10.0    58  1:34:50.616      5690616
# 9               1              1      10.0    58  1:34:50.616      5690616
# 10              1              1      10.0    58  1:34:50.616      5690616
# 11              1              1      10.0    58  1:34:50.616      5690616
# 12              1              1      10.0    58  1:34:50.616      5690616
# 13              1              1      10.0    58  1:34:50.616      5690616
# 14              1              1      10.0    58  1:34:50.616      5690616
# 15              1              1      10.0    58  1:34:50.616      5690616
# 16              1              1      10.0    58  1:34:50.616      5690616
# 17              1              1      10.0    58  1:34:50.616      5690616
# 18              1              1      10.0    58  1:34:50.616      5690616
# 19              1              1      10.0    58  1:34:50.616      5690616
#
#    fastestLap rank fastestLapTime fastestLapSpeed  statusId driverRef  \
# 0          39    2       1:27.452         218.300         1  hamilton
# 1          39    2       1:27.452         218.300         1  hamilton
# 2          39    2       1:27.452         218.300         1  hamilton
# 3          39    2       1:27.452         218.300         1  hamilton
# 4          39    2       1:27.452         218.300         1  hamilton
# 5          39    2       1:27.452         218.300         1  hamilton
# 6          39    2       1:27.452         218.300         1  hamilton
# 7          39    2       1:27.452         218.300         1  hamilton
# 8          39    2       1:27.452         218.300         1  hamilton
# 9          39    2       1:27.452         218.300         1  hamilton
# 10         39    2       1:27.452         218.300         1  hamilton
# 11         39    2       1:27.452         218.300         1  hamilton
# 12         39    2       1:27.452         218.300         1  hamilton
# 13         39    2       1:27.452         218.300         1  hamilton
# 14         39    2       1:27.452         218.300         1  hamilton
# 15         39    2       1:27.452         218.300         1  hamilton
# 16         39    2       1:27.452         218.300         1  hamilton
# 17         39    2       1:27.452         218.300         1  hamilton
# 18         39    2       1:27.452         218.300         1  hamilton
# 19         39    2       1:27.452         218.300         1  hamilton
#
#    number_y code forename   surname         dob nationality_x  \
# 0        44  HAM    Lewis  Hamilton  1985-01-07       British
# 1        44  HAM    Lewis  Hamilton  1985-01-07       British
# 2        44  HAM    Lewis  Hamilton  1985-01-07       British
# 3        44  HAM    Lewis  Hamilton  1985-01-07       British
# 4        44  HAM    Lewis  Hamilton  1985-01-07       British
# 5        44  HAM    Lewis  Hamilton  1985-01-07       British
# 6        44  HAM    Lewis  Hamilton  1985-01-07       British
# 7        44  HAM    Lewis  Hamilton  1985-01-07       British
# 8        44  HAM    Lewis  Hamilton  1985-01-07       British
# 9        44  HAM    Lewis  Hamilton  1985-01-07       British
# 10       44  HAM    Lewis  Hamilton  1985-01-07       British
# 11       44  HAM    Lewis  Hamilton  1985-01-07       British
# 12       44  HAM    Lewis  Hamilton  1985-01-07       British
# 13       44  HAM    Lewis  Hamilton  1985-01-07       British
# 14       44  HAM    Lewis  Hamilton  1985-01-07       British
# 15       44  HAM    Lewis  Hamilton  1985-01-07       British
# 16       44  HAM    Lewis  Hamilton  1985-01-07       British
# 17       44  HAM    Lewis  Hamilton  1985-01-07       British
# 18       44  HAM    Lewis  Hamilton  1985-01-07       British
# 19       44  HAM    Lewis  Hamilton  1985-01-07       British
#
#                                           url_x  driverStandingsId  raceId_y  \
# 0   http://en.wikipedia.org/wiki/Lewis_Hamilton                  1        18
# 1   http://en.wikipedia.org/wiki/Lewis_Hamilton                  9        19
# 2   http://en.wikipedia.org/wiki/Lewis_Hamilton                 27        20
# 3   http://en.wikipedia.org/wiki/Lewis_Hamilton                 48        21
# 4   http://en.wikipedia.org/wiki/Lewis_Hamilton                 69        22
# 5   http://en.wikipedia.org/wiki/Lewis_Hamilton                 91        23
# 6   http://en.wikipedia.org/wiki/Lewis_Hamilton                113        24
# 7   http://en.wikipedia.org/wiki/Lewis_Hamilton                135        25
# 8   http://en.wikipedia.org/wiki/Lewis_Hamilton                157        26
# 9   http://en.wikipedia.org/wiki/Lewis_Hamilton                179        27
# 10  http://en.wikipedia.org/wiki/Lewis_Hamilton                201        28
# 11  http://en.wikipedia.org/wiki/Lewis_Hamilton                223        29
# 12  http://en.wikipedia.org/wiki/Lewis_Hamilton                245        30
# 13  http://en.wikipedia.org/wiki/Lewis_Hamilton                267        31
# 14  http://en.wikipedia.org/wiki/Lewis_Hamilton                289        32
# 15  http://en.wikipedia.org/wiki/Lewis_Hamilton                311        33
# 16  http://en.wikipedia.org/wiki/Lewis_Hamilton               3438        34
# 17  http://en.wikipedia.org/wiki/Lewis_Hamilton                355        35
# 18  http://en.wikipedia.org/wiki/Lewis_Hamilton              13652        38
# 19  http://en.wikipedia.org/wiki/Lewis_Hamilton              68157       969
#
#     points_y  position_y positionText_y  wins constructorRef     name  \
# 0       10.0           1              1     1        mclaren  McLaren
# 1       14.0           1              1     1        mclaren  McLaren
# 2       14.0           3              3     1        mclaren  McLaren
# 3       20.0           2              2     1        mclaren  McLaren
# 4       28.0           3              3     1        mclaren  McLaren
# 5       38.0           1              1     2        mclaren  McLaren
# 6       38.0           2              2     2        mclaren  McLaren
# 7       38.0           4              4     2        mclaren  McLaren
# 8       48.0           1              1     3        mclaren  McLaren
# 9       58.0           1              1     4        mclaren  McLaren
# 10      62.0           1              1     4        mclaren  McLaren
# 11      70.0           1              1     4        mclaren  McLaren
# 12      76.0           1              1     4        mclaren  McLaren
# 13      78.0           1              1     4        mclaren  McLaren
# 14      84.0           1              1     4        mclaren  McLaren
# 15      84.0           1              1     4        mclaren  McLaren
# 16      94.0           1              1     5        mclaren  McLaren
# 17      98.0           1              1     5        mclaren  McLaren
# 18      22.0           3              3     0        mclaren  McLaren
# 19      18.0           2              2     0        mclaren  McLaren
#
#    nationality_y                                 url_y    status
# 0        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 1        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 2        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 3        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 4        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 5        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 6        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 7        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 8        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 9        British  http://en.wikipedia.org/wiki/McLaren  Finished
# 10       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 11       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 12       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 13       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 14       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 15       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 16       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 17       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 18       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 19       British  http://en.wikipedia.org/wiki/McLaren  Finished

# %%
# droping unwanted columns 

df = df.drop(['position_x'],1)

# %%
df.head(10)
# Out:
#    resultId  raceId_x  driverId  constructorId number_x  grid positionText_x  \
# 0         1        18         1              1       22     1              1
# 1         1        18         1              1       22     1              1
# 2         1        18         1              1       22     1              1
# 3         1        18         1              1       22     1              1
# 4         1        18         1              1       22     1              1
# 5         1        18         1              1       22     1              1
# 6         1        18         1              1       22     1              1
# 7         1        18         1              1       22     1              1
# 8         1        18         1              1       22     1              1
# 9         1        18         1              1       22     1              1
#
#    positionOrder  points_x  laps         time milliseconds fastestLap rank  \
# 0              1      10.0    58  1:34:50.616      5690616         39    2
# 1              1      10.0    58  1:34:50.616      5690616         39    2
# 2              1      10.0    58  1:34:50.616      5690616         39    2
# 3              1      10.0    58  1:34:50.616      5690616         39    2
# 4              1      10.0    58  1:34:50.616      5690616         39    2
# 5              1      10.0    58  1:34:50.616      5690616         39    2
# 6              1      10.0    58  1:34:50.616      5690616         39    2
# 7              1      10.0    58  1:34:50.616      5690616         39    2
# 8              1      10.0    58  1:34:50.616      5690616         39    2
# 9              1      10.0    58  1:34:50.616      5690616         39    2
#
#   fastestLapTime fastestLapSpeed  statusId driverRef number_y code forename  \
# 0       1:27.452         218.300         1  hamilton       44  HAM    Lewis
# 1       1:27.452         218.300         1  hamilton       44  HAM    Lewis
# 2       1:27.452         218.300         1  hamilton       44  HAM    Lewis
# 3       1:27.452         218.300         1  hamilton       44  HAM    Lewis
# 4       1:27.452         218.300         1  hamilton       44  HAM    Lewis
# 5       1:27.452         218.300         1  hamilton       44  HAM    Lewis
# 6       1:27.452         218.300         1  hamilton       44  HAM    Lewis
# 7       1:27.452         218.300         1  hamilton       44  HAM    Lewis
# 8       1:27.452         218.300         1  hamilton       44  HAM    Lewis
# 9       1:27.452         218.300         1  hamilton       44  HAM    Lewis
#
#     surname         dob nationality_x  \
# 0  Hamilton  1985-01-07       British
# 1  Hamilton  1985-01-07       British
# 2  Hamilton  1985-01-07       British
# 3  Hamilton  1985-01-07       British
# 4  Hamilton  1985-01-07       British
# 5  Hamilton  1985-01-07       British
# 6  Hamilton  1985-01-07       British
# 7  Hamilton  1985-01-07       British
# 8  Hamilton  1985-01-07       British
# 9  Hamilton  1985-01-07       British
#
#                                          url_x  driverStandingsId  raceId_y  \
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton                  1        18
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton                  9        19
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton                 27        20
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton                 48        21
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton                 69        22
# 5  http://en.wikipedia.org/wiki/Lewis_Hamilton                 91        23
# 6  http://en.wikipedia.org/wiki/Lewis_Hamilton                113        24
# 7  http://en.wikipedia.org/wiki/Lewis_Hamilton                135        25
# 8  http://en.wikipedia.org/wiki/Lewis_Hamilton                157        26
# 9  http://en.wikipedia.org/wiki/Lewis_Hamilton                179        27
#
#    points_y  position_y positionText_y  wins constructorRef     name  \
# 0      10.0           1              1     1        mclaren  McLaren
# 1      14.0           1              1     1        mclaren  McLaren
# 2      14.0           3              3     1        mclaren  McLaren
# 3      20.0           2              2     1        mclaren  McLaren
# 4      28.0           3              3     1        mclaren  McLaren
# 5      38.0           1              1     2        mclaren  McLaren
# 6      38.0           2              2     2        mclaren  McLaren
# 7      38.0           4              4     2        mclaren  McLaren
# 8      48.0           1              1     3        mclaren  McLaren
# 9      58.0           1              1     4        mclaren  McLaren
#
#   nationality_y                                 url_y    status
# 0       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 1       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 2       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 3       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 4       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 5       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 6       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 7       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 8       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 9       British  http://en.wikipedia.org/wiki/McLaren  Finished

# %%
# changing of old column name to meaningful name 

col_name = {'number_x':'number','milliseconds':'timetaken_in_millisec','fastestLapSpeed':'max_speed',
 'name_x':'grand_prix','number_y':'driver_num','code':'driver_code','nationality_x':'nationality','name_y':'company',
 'raceId_x':'racerId','points_x':'points','position_y':'position'}

df.rename(columns=col_name,inplace=True)
df.head()
# Out:
#    resultId  racerId  driverId  constructorId number  grid positionText_x  \
# 0         1       18         1              1     22     1              1
# 1         1       18         1              1     22     1              1
# 2         1       18         1              1     22     1              1
# 3         1       18         1              1     22     1              1
# 4         1       18         1              1     22     1              1
#
#    positionOrder  points  laps         time timetaken_in_millisec fastestLap  \
# 0              1    10.0    58  1:34:50.616               5690616         39
# 1              1    10.0    58  1:34:50.616               5690616         39
# 2              1    10.0    58  1:34:50.616               5690616         39
# 3              1    10.0    58  1:34:50.616               5690616         39
# 4              1    10.0    58  1:34:50.616               5690616         39
#
#   rank fastestLapTime max_speed  statusId driverRef driver_num driver_code  \
# 0    2       1:27.452   218.300         1  hamilton         44         HAM
# 1    2       1:27.452   218.300         1  hamilton         44         HAM
# 2    2       1:27.452   218.300         1  hamilton         44         HAM
# 3    2       1:27.452   218.300         1  hamilton         44         HAM
# 4    2       1:27.452   218.300         1  hamilton         44         HAM
#
#   forename   surname         dob nationality  \
# 0    Lewis  Hamilton  1985-01-07     British
# 1    Lewis  Hamilton  1985-01-07     British
# 2    Lewis  Hamilton  1985-01-07     British
# 3    Lewis  Hamilton  1985-01-07     British
# 4    Lewis  Hamilton  1985-01-07     British
#
#                                          url_x  driverStandingsId  raceId_y  \
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton                  1        18
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton                  9        19
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton                 27        20
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton                 48        21
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton                 69        22
#
#    points_y  position positionText_y  wins constructorRef     name  \
# 0      10.0         1              1     1        mclaren  McLaren
# 1      14.0         1              1     1        mclaren  McLaren
# 2      14.0         3              3     1        mclaren  McLaren
# 3      20.0         2              2     1        mclaren  McLaren
# 4      28.0         3              3     1        mclaren  McLaren
#
#   nationality_y                                 url_y    status
# 0       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 1       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 2       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 3       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 4       British  http://en.wikipedia.org/wiki/McLaren  Finished

# %% [markdown]
# ![overtake](https://c.tenor.com/IB4EgSxeYREAAAAd/f1-max-verstappen.gif)

# %%
# Adding two column (forename,surname) to create a single column called driver_name

df['driver_name'] = df['forename']+' '+df['surname']

# %%
df.head()
# Out:
#    resultId  racerId  driverId  constructorId number  grid positionText_x  \
# 0         1       18         1              1     22     1              1
# 1         1       18         1              1     22     1              1
# 2         1       18         1              1     22     1              1
# 3         1       18         1              1     22     1              1
# 4         1       18         1              1     22     1              1
#
#    positionOrder  points  laps         time timetaken_in_millisec fastestLap  \
# 0              1    10.0    58  1:34:50.616               5690616         39
# 1              1    10.0    58  1:34:50.616               5690616         39
# 2              1    10.0    58  1:34:50.616               5690616         39
# 3              1    10.0    58  1:34:50.616               5690616         39
# 4              1    10.0    58  1:34:50.616               5690616         39
#
#   rank fastestLapTime max_speed  statusId driverRef driver_num driver_code  \
# 0    2       1:27.452   218.300         1  hamilton         44         HAM
# 1    2       1:27.452   218.300         1  hamilton         44         HAM
# 2    2       1:27.452   218.300         1  hamilton         44         HAM
# 3    2       1:27.452   218.300         1  hamilton         44         HAM
# 4    2       1:27.452   218.300         1  hamilton         44         HAM
#
#   forename   surname         dob nationality  \
# 0    Lewis  Hamilton  1985-01-07     British
# 1    Lewis  Hamilton  1985-01-07     British
# 2    Lewis  Hamilton  1985-01-07     British
# 3    Lewis  Hamilton  1985-01-07     British
# 4    Lewis  Hamilton  1985-01-07     British
#
#                                          url_x  driverStandingsId  raceId_y  \
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton                  1        18
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton                  9        19
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton                 27        20
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton                 48        21
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton                 69        22
#
#    points_y  position positionText_y  wins constructorRef     name  \
# 0      10.0         1              1     1        mclaren  McLaren
# 1      14.0         1              1     1        mclaren  McLaren
# 2      14.0         3              3     1        mclaren  McLaren
# 3      20.0         2              2     1        mclaren  McLaren
# 4      28.0         3              3     1        mclaren  McLaren
#
#   nationality_y                                 url_y    status  \
# 0       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 1       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 2       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 3       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 4       British  http://en.wikipedia.org/wiki/McLaren  Finished
#
#       driver_name
# 0  Lewis Hamilton
# 1  Lewis Hamilton
# 2  Lewis Hamilton
# 3  Lewis Hamilton
# 4  Lewis Hamilton

# %%
df = df.drop(['forename','surname'],1)

# %%
df.head()
# Out:
#    resultId  racerId  driverId  constructorId number  grid positionText_x  \
# 0         1       18         1              1     22     1              1
# 1         1       18         1              1     22     1              1
# 2         1       18         1              1     22     1              1
# 3         1       18         1              1     22     1              1
# 4         1       18         1              1     22     1              1
#
#    positionOrder  points  laps         time timetaken_in_millisec fastestLap  \
# 0              1    10.0    58  1:34:50.616               5690616         39
# 1              1    10.0    58  1:34:50.616               5690616         39
# 2              1    10.0    58  1:34:50.616               5690616         39
# 3              1    10.0    58  1:34:50.616               5690616         39
# 4              1    10.0    58  1:34:50.616               5690616         39
#
#   rank fastestLapTime max_speed  statusId driverRef driver_num driver_code  \
# 0    2       1:27.452   218.300         1  hamilton         44         HAM
# 1    2       1:27.452   218.300         1  hamilton         44         HAM
# 2    2       1:27.452   218.300         1  hamilton         44         HAM
# 3    2       1:27.452   218.300         1  hamilton         44         HAM
# 4    2       1:27.452   218.300         1  hamilton         44         HAM
#
#           dob nationality                                        url_x  \
# 0  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
#    driverStandingsId  raceId_y  points_y  position positionText_y  wins  \
# 0                  1        18      10.0         1              1     1
# 1                  9        19      14.0         1              1     1
# 2                 27        20      14.0         3              3     1
# 3                 48        21      20.0         2              2     1
# 4                 69        22      28.0         3              3     1
#
#   constructorRef     name nationality_y                                 url_y  \
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
#      status     driver_name
# 0  Finished  Lewis Hamilton
# 1  Finished  Lewis Hamilton
# 2  Finished  Lewis Hamilton
# 3  Finished  Lewis Hamilton
# 4  Finished  Lewis Hamilton

# %% [markdown]
# # Converting dtype
#
# Changing of data type from object to date to calculate the driver's age.

# %%
df.head()
# Out:
#    resultId  racerId  driverId  constructorId number  grid positionText_x  \
# 0         1       18         1              1     22     1              1
# 1         1       18         1              1     22     1              1
# 2         1       18         1              1     22     1              1
# 3         1       18         1              1     22     1              1
# 4         1       18         1              1     22     1              1
#
#    positionOrder  points  laps         time timetaken_in_millisec fastestLap  \
# 0              1    10.0    58  1:34:50.616               5690616         39
# 1              1    10.0    58  1:34:50.616               5690616         39
# 2              1    10.0    58  1:34:50.616               5690616         39
# 3              1    10.0    58  1:34:50.616               5690616         39
# 4              1    10.0    58  1:34:50.616               5690616         39
#
#   rank fastestLapTime max_speed  statusId driverRef driver_num driver_code  \
# 0    2       1:27.452   218.300         1  hamilton         44         HAM
# 1    2       1:27.452   218.300         1  hamilton         44         HAM
# 2    2       1:27.452   218.300         1  hamilton         44         HAM
# 3    2       1:27.452   218.300         1  hamilton         44         HAM
# 4    2       1:27.452   218.300         1  hamilton         44         HAM
#
#           dob nationality                                        url_x  \
# 0  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4  1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
#    driverStandingsId  raceId_y  points_y  position positionText_y  wins  \
# 0                  1        18      10.0         1              1     1
# 1                  9        19      14.0         1              1     1
# 2                 27        20      14.0         3              3     1
# 3                 48        21      20.0         2              2     1
# 4                 69        22      28.0         3              3     1
#
#   constructorRef     name nationality_y                                 url_y  \
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
#      status     driver_name
# 0  Finished  Lewis Hamilton
# 1  Finished  Lewis Hamilton
# 2  Finished  Lewis Hamilton
# 3  Finished  Lewis Hamilton
# 4  Finished  Lewis Hamilton

# %%
# converting to date format from string 

pd.to_datetime(df.dob)
# Out:
# 0         1985-01-07
# 1         1985-01-07
# 2         1985-01-07
# 3         1985-01-07
# 4         1985-01-07
#              ...
# 3537622   1913-05-05
# 3537623   1913-05-05
# 3537624   1913-05-05
# 3537625   1913-05-05
# 3537626   1913-05-05
# Name: dob, Length: 3537627, dtype: datetime64[ns]

# %%
df['dob'] = pd.to_datetime(df['dob'])

# %%
from datetime import datetime

# %%
# calculating driver's age and creating it as a new column

dates = datetime.today()-df['dob']
age = dates.dt.days/365

# %%
df['age'] = round(age)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    resultId  racerId  driverId  constructorId number  grid positionText_x  \
# 0         1       18         1              1     22     1              1
# 1         1       18         1              1     22     1              1
# 2         1       18         1              1     22     1              1
# 3         1       18         1              1     22     1              1
# 4         1       18         1              1     22     1              1
#
#    positionOrder  points  laps         time timetaken_in_millisec fastestLap  \
# 0              1    10.0    58  1:34:50.616               5690616         39
# 1              1    10.0    58  1:34:50.616               5690616         39
# 2              1    10.0    58  1:34:50.616               5690616         39
# 3              1    10.0    58  1:34:50.616               5690616         39
# 4              1    10.0    58  1:34:50.616               5690616         39
#
#   rank fastestLapTime max_speed  statusId driverRef driver_num driver_code  \
# 0    2       1:27.452   218.300         1  hamilton         44         HAM
# 1    2       1:27.452   218.300         1  hamilton         44         HAM
# 2    2       1:27.452   218.300         1  hamilton         44         HAM
# 3    2       1:27.452   218.300         1  hamilton         44         HAM
# 4    2       1:27.452   218.300         1  hamilton         44         HAM
#
#          dob nationality                                        url_x  \
# 0 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
#    driverStandingsId  raceId_y  points_y  position positionText_y  wins  \
# 0                  1        18      10.0         1              1     1
# 1                  9        19      14.0         1              1     1
# 2                 27        20      14.0         3              3     1
# 3                 48        21      20.0         2              2     1
# 4                 69        22      28.0         3              3     1
#
#   constructorRef     name nationality_y                                 url_y  \
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
#      status     driver_name   age
# 0  Finished  Lewis Hamilton  39.0
# 1  Finished  Lewis Hamilton  39.0
# 2  Finished  Lewis Hamilton  39.0
# 3  Finished  Lewis Hamilton  39.0
# 4  Finished  Lewis Hamilton  39.0

# %%
# changing datatype

l = ['number','timetaken_in_millisec','fastestLap','rank','max_speed','driver_num']
for i in l:
    df[i] = pd.to_numeric(df[i],errors='coerce')

# %%
df.drop('driver_num',1,inplace=True)

# %%
# seperating categorical and numerical columns for understading 

cat = []
num = []
for i in df.columns:
    if df[i].dtypes == 'O':
        cat.append(i)
    else:
        num.append(i)

# %%
df[cat].head()
# Out:
#   positionText_x         time fastestLapTime driverRef driver_code  \
# 0              1  1:34:50.616       1:27.452  hamilton         HAM
# 1              1  1:34:50.616       1:27.452  hamilton         HAM
# 2              1  1:34:50.616       1:27.452  hamilton         HAM
# 3              1  1:34:50.616       1:27.452  hamilton         HAM
# 4              1  1:34:50.616       1:27.452  hamilton         HAM
#
#   nationality                                        url_x positionText_y  \
# 0     British  http://en.wikipedia.org/wiki/Lewis_Hamilton              1
# 1     British  http://en.wikipedia.org/wiki/Lewis_Hamilton              1
# 2     British  http://en.wikipedia.org/wiki/Lewis_Hamilton              3
# 3     British  http://en.wikipedia.org/wiki/Lewis_Hamilton              2
# 4     British  http://en.wikipedia.org/wiki/Lewis_Hamilton              3
#
#   constructorRef     name nationality_y                                 url_y  \
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
#      status     driver_name
# 0  Finished  Lewis Hamilton
# 1  Finished  Lewis Hamilton
# 2  Finished  Lewis Hamilton
# 3  Finished  Lewis Hamilton
# 4  Finished  Lewis Hamilton

# %%
df[num].head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid  positionOrder  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    points  laps  timetaken_in_millisec  fastestLap  rank  max_speed  statusId  \
# 0    10.0    58              5690616.0        39.0   2.0      218.3         1
# 1    10.0    58              5690616.0        39.0   2.0      218.3         1
# 2    10.0    58              5690616.0        39.0   2.0      218.3         1
# 3    10.0    58              5690616.0        39.0   2.0      218.3         1
# 4    10.0    58              5690616.0        39.0   2.0      218.3         1
#
#          dob  driverStandingsId  raceId_y  points_y  position  wins   age
# 0 1985-01-07                  1        18      10.0         1     1  39.0
# 1 1985-01-07                  9        19      14.0         1     1  39.0
# 2 1985-01-07                 27        20      14.0         3     1  39.0
# 3 1985-01-07                 48        21      20.0         2     1  39.0
# 4 1985-01-07                 69        22      28.0         3     1  39.0

# %%
df.dtypes
# Out:
# resultId                          int64
# racerId                           int64
# driverId                          int64
# constructorId                     int64
# number                          float64
# grid                              int64
# positionText_x                   object
# positionOrder                     int64
# points                          float64
# laps                              int64
# time                             object
# timetaken_in_millisec           float64
# fastestLap                      float64
# rank                            float64
# fastestLapTime                   object
# max_speed                       float64
# statusId                          int64
# driverRef                        object
# driver_code                      object
# dob                      datetime64[ns]
# nationality                      object
# url_x                            object
# driverStandingsId                 int64
# raceId_y                          int64
# points_y                        float64
# position                          int64
# positionText_y                   object
# wins                              int64
# constructorRef                   object
# name                             object
# nationality_y                    object
# url_y                            object
# status                           object
# driver_name                      object
# age                             float64
# dtype: object

# %%
df.head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid positionText_x  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    positionOrder  points  laps         time  timetaken_in_millisec  \
# 0              1    10.0    58  1:34:50.616              5690616.0
# 1              1    10.0    58  1:34:50.616              5690616.0
# 2              1    10.0    58  1:34:50.616              5690616.0
# 3              1    10.0    58  1:34:50.616              5690616.0
# 4              1    10.0    58  1:34:50.616              5690616.0
#
#    fastestLap  rank fastestLapTime  max_speed  statusId driverRef driver_code  \
# 0        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 1        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 2        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 3        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 4        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
#
#          dob nationality                                        url_x  \
# 0 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
#    driverStandingsId  raceId_y  points_y  position positionText_y  wins  \
# 0                  1        18      10.0         1              1     1
# 1                  9        19      14.0         1              1     1
# 2                 27        20      14.0         3              3     1
# 3                 48        21      20.0         2              2     1
# 4                 69        22      28.0         3              3     1
#
#   constructorRef     name nationality_y                                 url_y  \
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
#      status     driver_name   age
# 0  Finished  Lewis Hamilton  39.0
# 1  Finished  Lewis Hamilton  39.0
# 2  Finished  Lewis Hamilton  39.0
# 3  Finished  Lewis Hamilton  39.0
# 4  Finished  Lewis Hamilton  39.0

# %%
df.isnull().sum() / len(df) * 100
# Out:
# resultId                  0.000000
# racerId                   0.000000
# driverId                  0.000000
# constructorId             0.000000
# number                    0.004523
# grid                      0.000000
# positionText_x            0.000000
# positionOrder             0.000000
# points                    0.000000
# laps                      0.000000
# time                      0.000000
# timetaken_in_millisec    61.421936
# fastestLap               60.511100
# rank                     59.513764
# fastestLapTime            0.000000
# max_speed                60.511100
# statusId                  0.000000
# driverRef                 0.000000
# driver_code               0.000000
# dob                       0.000000
# nationality               0.000000
# url_x                     0.000000
# driverStandingsId         0.000000
# raceId_y                  0.000000
# points_y                  0.000000
# position                  0.000000
# positionText_y            0.000000
# wins                      0.000000
# constructorRef            0.000000
# name                      0.000000
# nationality_y             0.000000
# url_y                     0.000000
# status                    0.000000
# driver_name               0.000000
# age                       0.000000
# dtype: float64

# %%
df['max_speed'].mean()
# Out:
# 204.02159408791888

# %%
df[['rank','fastestLap']] = df[['rank','fastestLap']].fillna(0)
df['timetaken_in_millisec'] = df['timetaken_in_millisec'].fillna(df['timetaken_in_millisec'].mean())
df['max_speed']= df['max_speed'].fillna(df['max_speed'].mean())
df['number'] = df['number'].fillna(0)

# %%
df.isnull().sum() / len(df) * 100
# Out:
# resultId                 0.0
# racerId                  0.0
# driverId                 0.0
# constructorId            0.0
# number                   0.0
# grid                     0.0
# positionText_x           0.0
# positionOrder            0.0
# points                   0.0
# laps                     0.0
# time                     0.0
# timetaken_in_millisec    0.0
# fastestLap               0.0
# rank                     0.0
# fastestLapTime           0.0
# max_speed                0.0
# statusId                 0.0
# driverRef                0.0
# driver_code              0.0
# dob                      0.0
# nationality              0.0
# url_x                    0.0
# driverStandingsId        0.0
# raceId_y                 0.0
# points_y                 0.0
# position                 0.0
# positionText_y           0.0
# wins                     0.0
# constructorRef           0.0
# name                     0.0
# nationality_y            0.0
# url_y                    0.0
# status                   0.0
# driver_name              0.0
# age                      0.0
# dtype: float64

# %%
df.head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid positionText_x  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    positionOrder  points  laps         time  timetaken_in_millisec  \
# 0              1    10.0    58  1:34:50.616              5690616.0
# 1              1    10.0    58  1:34:50.616              5690616.0
# 2              1    10.0    58  1:34:50.616              5690616.0
# 3              1    10.0    58  1:34:50.616              5690616.0
# 4              1    10.0    58  1:34:50.616              5690616.0
#
#    fastestLap  rank fastestLapTime  max_speed  statusId driverRef driver_code  \
# 0        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 1        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 2        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 3        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 4        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
#
#          dob nationality                                        url_x  \
# 0 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
#    driverStandingsId  raceId_y  points_y  position positionText_y  wins  \
# 0                  1        18      10.0         1              1     1
# 1                  9        19      14.0         1              1     1
# 2                 27        20      14.0         3              3     1
# 3                 48        21      20.0         2              2     1
# 4                 69        22      28.0         3              3     1
#
#   constructorRef     name nationality_y                                 url_y  \
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
#      status     driver_name   age
# 0  Finished  Lewis Hamilton  39.0
# 1  Finished  Lewis Hamilton  39.0
# 2  Finished  Lewis Hamilton  39.0
# 3  Finished  Lewis Hamilton  39.0
# 4  Finished  Lewis Hamilton  39.0

# %%
df.describe().T
# Out:
#                            count          mean            std        min  \
# resultId               3537627.0  1.263009e+04    8209.508032       1.00
# racerId                3537627.0  5.170666e+02     331.536193       1.00
# driverId               3537627.0  2.041828e+02     265.852299       1.00
# constructorId          3537627.0  3.941215e+01      56.860468       1.00
# number                 3537627.0  1.541915e+01      13.997266       0.00
# grid                   3537627.0  9.763203e+00       6.557031       0.00
# positionOrder          3537627.0  1.122956e+01       7.378775       1.00
# points                 3537627.0  2.998598e+00       5.334331       0.00
# laps                   3537627.0  4.836204e+01      25.123229       0.00
# timetaken_in_millisec  3537627.0  5.955319e+06  760797.157790  207071.00
# fastestLap             3537627.0  1.690551e+01      23.399156       0.00
# rank                   3537627.0  3.615317e+00       5.749896       0.00
# max_speed              3537627.0  2.040216e+02      13.394752      89.54
# statusId               3537627.0  1.323813e+01      22.544512       1.00
# driverStandingsId      3537627.0  4.011746e+04   25309.272186       1.00
# raceId_y               3537627.0  5.193302e+02     331.962602       1.00
# points_y               3537627.0  2.839100e+01      52.047553       0.00
# position               3537627.0  1.165484e+01       9.133026       1.00
# wins                   3537627.0  5.517376e-01       1.452231       0.00
# age                    3537627.0  5.704437e+01      18.936796      23.00
#
#                                 25%           50%           75%          max
# resultId               5.125000e+03  1.176300e+04  2.114000e+04     26085.00
# racerId                2.340000e+02  4.670000e+02  8.560000e+02      1110.00
# driverId               2.000000e+01  1.050000e+02  2.290000e+02       858.00
# constructorId          6.000000e+00  1.600000e+01  3.700000e+01       214.00
# number                 6.000000e+00  1.200000e+01  2.100000e+01       208.00
# grid                   4.000000e+00  9.000000e+00  1.500000e+01        34.00
# positionOrder          5.000000e+00  1.000000e+01  1.700000e+01        39.00
# points                 0.000000e+00  0.000000e+00  4.000000e+00        50.00
# laps                   3.200000e+01  5.500000e+01  6.700000e+01       200.00
# timetaken_in_millisec  5.955319e+06  5.955319e+06  5.955319e+06  15090540.00
# fastestLap             0.000000e+00  0.000000e+00  4.000000e+01        85.00
# rank                   0.000000e+00  0.000000e+00  6.000000e+00        24.00
# max_speed              2.040216e+02  2.040216e+02  2.040216e+02       257.32
# statusId               1.000000e+00  5.000000e+00  1.200000e+01       141.00
# driverStandingsId      1.385600e+04  4.996000e+04  6.582400e+04     72187.00
# raceId_y               2.380000e+02  4.700000e+02  8.570000e+02      1110.00
# points_y               1.000000e+00  8.000000e+00  3.100000e+01       454.00
# position               5.000000e+00  1.000000e+01  1.600000e+01       108.00
# wins                   0.000000e+00  0.000000e+00  0.000000e+00        15.00
# age                    4.200000e+01  5.500000e+01  7.000000e+01       127.00

# %% [markdown]
# # Map
#
# The map is used to plot the track that are used all around the world using latitude and longitude.

# %%
circuit_df = pd.read_csv('./dataset/circuits.csv')
circuit_df.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park

# %% [markdown]
# # displaying the f1 track on the map using folium

# %%
# ploting the f1 track using lat and lng in worldmap

import folium
coordinates=[]
for lat,lng in zip(circuit_df['lat'],circuit_df['lng']):
    coordinates.append([lat,lng])
maps = folium.Map(zoom_start=150,tiles='Stamen Watercolor')  #map_types (Stamen Terrain, Stamen Toner, Mapbox Bright, cartodbpositron)
for i,j in zip(coordinates,circuit_df.name):
    marker = folium.Marker(
        location=i,
        icon=folium.Icon(icon="person",color='cadetblue',prefix='fa'),
        popup="<strong>{0}</strong>".format(j))  #strong is used to bold the font (optional)
    marker.add_to(maps)
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6dd180db6f64dd36fb38d6f325d7478 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6dd180db6f64dd36fb38d6f325d7478&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6dd180db6f64dd36fb38d6f325d7478 = L.map(
#                 &quot;map_a6dd180db6f64dd36fb38d6f325d7478&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb9b9e90160a1a67f1ec067d3dd7995e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6dd180db6f64dd36fb38d6f325d7478);
#
#
#             var marker_608a40cf866e10d6ff0b9f301b539098 = L.marker(
#                 [-37.8497, 144.968],
#                 {}
#             ).addTo(map_a6dd180db6f64dd36fb38d6f325d7478);
#
#
#             var icon_44c2a1130aad2ad9054dc31b22d92592 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_608a40cf866e10d6ff0b9f301b539098.setIcon(icon_44c2a1130aad2ad9054dc31b22d92592);
#
#
#         var popup_cedfa93f82bdbebf9c77e93043af8c07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c9ab7e42b7ec69da5685de17a9b9e813 = $(`&lt;div id=&quot;html_c9ab7e42b7ec69da5685de17a9b9e813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Albert Park Grand Prix Circuit&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_cedfa93f82bdbebf9c77e93043af8c07.setContent(html_c9ab7e42b7ec69da5685de17a9b9e813);
#
#
#
#         marker_608a40cf866e10d6ff0b9f301b539098.bindPopup(popup_cedfa93f82bdbebf9c77e93043af8c07)
#         ;
#
#
#
#
#             var marker_9a65db8eeaf9fd67f21952bd2862bb3f = L.marker(
#                 [2.76083, 101.738],
#                 {}
#             ).addTo(map_a6dd180db6f64dd36fb38d6f325d7478);
#
#
#             var icon_bfd1b11d3cb9bbe75dffcd42f1045d5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9a65db8eeaf9fd67f21952bd2862bb3f.setIcon(icon_bfd1b11d3cb9bbe75dffcd42f1045d5c);
#
#
#         var popup_5b304032ef2480c532e793694aced182 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0961ce284712ffbc4de70f7359c1590 = $(`&lt;div id=&quot;html_c0961ce284712ffbc4de70f7359c1590&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Sepang International Circuit&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_5b304032ef2480c532e793694aced182.setContent(html_c0961ce284712ffbc4de70f7359c1590);
#
#
#
#         marker_9a65db8eeaf9fd67f21952bd2862bb3f.bindPopup(popup_5b304032ef2480c532e793694aced182)
#         ;
#
#
#
#
#             var marker_36c9ea3bbb7a9c50214843c915bbab9e = L.marker(
#                 [26.0325, 50.5106],
#                 {}
#             ).addTo(map_a6dd180db6f64dd36fb38d6f325d7478);
#
#
#             var icon_9f364c11d9423d580be1e828c3bffda5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_36c9ea3bbb7a9c50214843c915bbab9e.setIcon(icon_9f364c11d9423d580be1e828c3bffda5);
#
#
#         var popup_03851c0ac82ce8d64d1ea366a2c7c6b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16cbd526190af838dd8907c9265cd05b = $(`&lt;div id=&quot;html_16cbd526190af838dd8907c9265cd05b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Bahrain International Circuit&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_03851c0ac82ce8d64d1ea366a2c7c6b7.setContent(html_16cbd526190af838dd8907c9265cd05b);
#
#
#
#         marker_36c9ea3bbb7a9c50214843c915bbab9e.bindPopup(popup_03851c0ac82ce8d64d1ea366a2c7c6b7)
#         ;

# %%
import folium
import pandas as pd

map = folium.Map

map.save('map.html')

# %%
df['rank'].unique()
# Out:
# array([ 2.,  3.,  6.,  5.,  4., 11.,  1., 12., 15., 10.,  9.,  8.,  7.,
#        18., 19., 13., 17.,  0., 14., 16., 20., 21., 22., 23., 24.])

# %% [markdown]
# # Data Filtration
#
# Filtering data by the driver who finished the race successfully

# %%
df_fin = df[df['status'] == 'Finished']
df_fin.tail()
# Out:
#          resultId  racerId  driverId  constructorId  number  grid  \
# 1363657     23346      967       839            209    31.0    22
# 1363658     23346      967       839            209    31.0    22
# 1363659     23346      967       839            209    31.0    22
# 1363660     23346      967       839            209    31.0    22
# 1363661     23346      967       839            209    31.0    22
#
#         positionText_x  positionOrder  points  laps     time  \
# 1363657             12             12     0.0    71  +45.809
# 1363658             12             12     0.0    71  +45.809
# 1363659             12             12     0.0    71  +45.809
# 1363660             12             12     0.0    71  +45.809
# 1363661             12             12     0.0    71  +45.809
#
#          timetaken_in_millisec  fastestLap  rank fastestLapTime  max_speed  \
# 1363657             10907144.0        47.0  16.0       1:27.796    176.686
# 1363658             10907144.0        47.0  16.0       1:27.796    176.686
# 1363659             10907144.0        47.0  16.0       1:27.796    176.686
# 1363660             10907144.0        47.0  16.0       1:27.796    176.686
# 1363661             10907144.0        47.0  16.0       1:27.796    176.686
#
#          statusId driverRef driver_code        dob nationality  \
# 1363657         1      ocon         OCO 1996-09-17      French
# 1363658         1      ocon         OCO 1996-09-17      French
# 1363659         1      ocon         OCO 1996-09-17      French
# 1363660         1      ocon         OCO 1996-09-17      French
# 1363661         1      ocon         OCO 1996-09-17      French
#
#                                              url_x  driverStandingsId  \
# 1363657  http://en.wikipedia.org/wiki/Esteban_Ocon              72083
# 1363658  http://en.wikipedia.org/wiki/Esteban_Ocon              72123
# 1363659  http://en.wikipedia.org/wiki/Esteban_Ocon              72143
# 1363660  http://en.wikipedia.org/wiki/Esteban_Ocon              72163
# 1363661  http://en.wikipedia.org/wiki/Esteban_Ocon              72184
#
#          raceId_y  points_y  position positionText_y  wins constructorRef  \
# 1363657      1106      29.0         9              9     0          manor
# 1363658      1107      31.0         9              9     0          manor
# 1363659      1108      31.0        10             10     0          manor
# 1363660      1109      31.0        10             10     0          manor
# 1363661      1110      35.0        10             10     0          manor
#
#                    name nationality_y  \
# 1363657  Manor Marussia       British
# 1363658  Manor Marussia       British
# 1363659  Manor Marussia       British
# 1363660  Manor Marussia       British
# 1363661  Manor Marussia       British
#
#                                                  url_y    status  \
# 1363657  http://en.wikipedia.org/wiki/Manor_Motorsport  Finished
# 1363658  http://en.wikipedia.org/wiki/Manor_Motorsport  Finished
# 1363659  http://en.wikipedia.org/wiki/Manor_Motorsport  Finished
# 1363660  http://en.wikipedia.org/wiki/Manor_Motorsport  Finished
# 1363661  http://en.wikipedia.org/wiki/Manor_Motorsport  Finished
#
#           driver_name   age
# 1363657  Esteban Ocon  27.0
# 1363658  Esteban Ocon  27.0
# 1363659  Esteban Ocon  27.0
# 1363660  Esteban Ocon  27.0
# 1363661  Esteban Ocon  27.0

# %%
mean = df.max_speed.mean()
mean2 = df.fastestLap.mean()
df = df_fin[df_fin['max_speed']>mean]
df.head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid positionText_x  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    positionOrder  points  laps         time  timetaken_in_millisec  \
# 0              1    10.0    58  1:34:50.616              5690616.0
# 1              1    10.0    58  1:34:50.616              5690616.0
# 2              1    10.0    58  1:34:50.616              5690616.0
# 3              1    10.0    58  1:34:50.616              5690616.0
# 4              1    10.0    58  1:34:50.616              5690616.0
#
#    fastestLap  rank fastestLapTime  max_speed  statusId driverRef driver_code  \
# 0        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 1        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 2        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 3        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 4        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
#
#          dob nationality                                        url_x  \
# 0 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
#    driverStandingsId  raceId_y  points_y  position positionText_y  wins  \
# 0                  1        18      10.0         1              1     1
# 1                  9        19      14.0         1              1     1
# 2                 27        20      14.0         3              3     1
# 3                 48        21      20.0         2              2     1
# 4                 69        22      28.0         3              3     1
#
#   constructorRef     name nationality_y                                 url_y  \
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
#      status     driver_name   age
# 0  Finished  Lewis Hamilton  39.0
# 1  Finished  Lewis Hamilton  39.0
# 2  Finished  Lewis Hamilton  39.0
# 3  Finished  Lewis Hamilton  39.0
# 4  Finished  Lewis Hamilton  39.0

# %%
df[df['fastestLap']>mean2]
# Out:
#          resultId  racerId  driverId  constructorId  number  grid  \
# 0               1       18         1              1    22.0     1
# 1               1       18         1              1    22.0     1
# 2               1       18         1              1    22.0     1
# 3               1       18         1              1    22.0     1
# 4               1       18         1              1    22.0     1
# ...           ...      ...       ...            ...     ...   ...
# 1363488     26042     1108       856            213    21.0    18
# 1363489     26042     1108       856            213    21.0    18
# 1363490     26042     1108       856            213    21.0    18
# 1363491     26042     1108       856            213    21.0    18
# 1363492     26042     1108       856            213    21.0    18
#
#         positionText_x  positionOrder  points  laps         time  \
# 0                    1              1    10.0    58  1:34:50.616
# 1                    1              1    10.0    58  1:34:50.616
# 2                    1              1    10.0    58  1:34:50.616
# 3                    1              1    10.0    58  1:34:50.616
# 4                    1              1    10.0    58  1:34:50.616
# ...                ...            ...     ...   ...          ...
# 1363488             17             17     0.0    52      +33.128
# 1363489             17             17     0.0    52      +33.128
# 1363490             17             17     0.0    52      +33.128
# 1363491             17             17     0.0    52      +33.128
# 1363492             17             17     0.0    52      +33.128
#
#          timetaken_in_millisec  fastestLap  rank fastestLapTime  max_speed  \
# 0                    5690616.0        39.0   2.0       1:27.452    218.300
# 1                    5690616.0        39.0   2.0       1:27.452    218.300
# 2                    5690616.0        39.0   2.0       1:27.452    218.300
# 3                    5690616.0        39.0   2.0       1:27.452    218.300
# 4                    5690616.0        39.0   2.0       1:27.452    218.300
# ...                        ...         ...   ...            ...        ...
# 1363488              5150066.0        48.0  18.0       1:32.353    229.636
# 1363489              5150066.0        48.0  18.0       1:32.353    229.636
# 1363490              5150066.0        48.0  18.0       1:32.353    229.636
# 1363491              5150066.0        48.0  18.0       1:32.353    229.636
# 1363492              5150066.0        48.0  18.0       1:32.353    229.636
#
#          statusId driverRef driver_code        dob nationality  \
# 0               1  hamilton         HAM 1985-01-07     British
# 1               1  hamilton         HAM 1985-01-07     British
# 2               1  hamilton         HAM 1985-01-07     British
# 3               1  hamilton         HAM 1985-01-07     British
# 4               1  hamilton         HAM 1985-01-07     British
# ...           ...       ...         ...        ...         ...
# 1363488         1  de_vries         DEV 1995-02-06       Dutch
# 1363489         1  de_vries         DEV 1995-02-06       Dutch
# 1363490         1  de_vries         DEV 1995-02-06       Dutch
# 1363491         1  de_vries         DEV 1995-02-06       Dutch
# 1363492         1  de_vries         DEV 1995-02-06       Dutch
#
#                                                url_x  driverStandingsId  \
# 0        http://en.wikipedia.org/wiki/Lewis_Hamilton                  1
# 1        http://en.wikipedia.org/wiki/Lewis_Hamilton                  9
# 2        http://en.wikipedia.org/wiki/Lewis_Hamilton                 27
# 3        http://en.wikipedia.org/wiki/Lewis_Hamilton                 48
# 4        http://en.wikipedia.org/wiki/Lewis_Hamilton                 69
# ...                                              ...                ...
# 1363488   http://en.wikipedia.org/wiki/Nyck_de_Vries              72079
# 1363489   http://en.wikipedia.org/wiki/Nyck_de_Vries              72119
# 1363490   http://en.wikipedia.org/wiki/Nyck_de_Vries              72139
# 1363491   http://en.wikipedia.org/wiki/Nyck_de_Vries              72159
# 1363492   http://en.wikipedia.org/wiki/Nyck_de_Vries              72180
#
#          raceId_y  points_y  position positionText_y  wins constructorRef  \
# 0              18      10.0         1              1     1        mclaren
# 1              19      14.0         1              1     1        mclaren
# 2              20      14.0         3              3     1        mclaren
# 3              21      20.0         2              2     1        mclaren
# 4              22      28.0         3              3     1        mclaren
# ...           ...       ...       ...            ...   ...            ...
# 1363488      1106       0.0        19             19     0     alphatauri
# 1363489      1107       0.0        20             20     0     alphatauri
# 1363490      1108       0.0        20             20     0     alphatauri
# 1363491      1109       0.0        20             20     0     alphatauri
# 1363492      1110       0.0        20             20     0     alphatauri
#
#                name nationality_y  \
# 0           McLaren       British
# 1           McLaren       British
# 2           McLaren       British
# 3           McLaren       British
# 4           McLaren       British
# ...             ...           ...
# 1363488  AlphaTauri       Italian
# 1363489  AlphaTauri       Italian
# 1363490  AlphaTauri       Italian
# 1363491  AlphaTauri       Italian
# 1363492  AlphaTauri       Italian
#
#                                                     url_y    status  \
# 0                    http://en.wikipedia.org/wiki/McLaren  Finished
# 1                    http://en.wikipedia.org/wiki/McLaren  Finished
# 2                    http://en.wikipedia.org/wiki/McLaren  Finished
# 3                    http://en.wikipedia.org/wiki/McLaren  Finished
# 4                    http://en.wikipedia.org/wiki/McLaren  Finished
# ...                                                   ...       ...
# 1363488  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri  Finished
# 1363489  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri  Finished
# 1363490  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri  Finished
# 1363491  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri  Finished
# 1363492  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri  Finished
#
#             driver_name   age
# 0        Lewis Hamilton  39.0
# 1        Lewis Hamilton  39.0
# 2        Lewis Hamilton  39.0
# 3        Lewis Hamilton  39.0
# 4        Lewis Hamilton  39.0
# ...                 ...   ...
# 1363488   Nyck de Vries  29.0
# 1363489   Nyck de Vries  29.0
# 1363490   Nyck de Vries  29.0
# 1363491   Nyck de Vries  29.0
# 1363492   Nyck de Vries  29.0
#
# [462834 rows x 35 columns]

# %%
# filtering the data by mean of driver's age

df = df[df['age']<df['age'].mean()]
df.head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid positionText_x  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    positionOrder  points  laps         time  timetaken_in_millisec  \
# 0              1    10.0    58  1:34:50.616              5690616.0
# 1              1    10.0    58  1:34:50.616              5690616.0
# 2              1    10.0    58  1:34:50.616              5690616.0
# 3              1    10.0    58  1:34:50.616              5690616.0
# 4              1    10.0    58  1:34:50.616              5690616.0
#
#    fastestLap  rank fastestLapTime  max_speed  statusId driverRef driver_code  \
# 0        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 1        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 2        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 3        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
# 4        39.0   2.0       1:27.452      218.3         1  hamilton         HAM
#
#          dob nationality                                        url_x  \
# 0 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4 1985-01-07     British  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
#    driverStandingsId  raceId_y  points_y  position positionText_y  wins  \
# 0                  1        18      10.0         1              1     1
# 1                  9        19      14.0         1              1     1
# 2                 27        20      14.0         3              3     1
# 3                 48        21      20.0         2              2     1
# 4                 69        22      28.0         3              3     1
#
#   constructorRef     name nationality_y                                 url_y  \
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
#      status     driver_name   age
# 0  Finished  Lewis Hamilton  39.0
# 1  Finished  Lewis Hamilton  39.0
# 2  Finished  Lewis Hamilton  39.0
# 3  Finished  Lewis Hamilton  39.0
# 4  Finished  Lewis Hamilton  39.0

# %%
# droping unwanted columns

df.drop('dob',1,inplace=True)
df.drop('statusId',1,inplace=True)

# %% [markdown]
# # Skewness
#
# Checking for skewness in the data, Skewness is used to check the normality of the data by ranging from -1 to 1.
# * -1 --> Left skewed
# * 0 --> Normal distribution
# * 1 --> Right skewed

# %%
df.skew()
# Out:
# resultId                -0.258324
# racerId                 -0.126828
# driverId                 1.121618
# constructorId            1.788285
# number                   2.105417
# grid                     0.904464
# positionText_x           0.926466
# positionOrder            0.926466
# points                   0.996958
# laps                    -0.887817
# timetaken_in_millisec    0.511147
# fastestLap              -0.561921
# rank                     0.770326
# max_speed                0.921027
# driverStandingsId       -0.630577
# raceId_y                -0.260034
# points_y                 2.014449
# position                 0.702424
# positionText_y           0.702424
# wins                     3.218526
# age                     -0.278560
# dtype: float64

# %% [markdown]
# # Outlier Treatment
#
# Seems some columns are skewed a lot, removal of the outliers will normalize a data bit

# %%
# outlier removal 

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
df = df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]
df.head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid positionText_x  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    positionOrder  points  laps         time  timetaken_in_millisec  \
# 0              1    10.0    58  1:34:50.616              5690616.0
# 1              1    10.0    58  1:34:50.616              5690616.0
# 2              1    10.0    58  1:34:50.616              5690616.0
# 3              1    10.0    58  1:34:50.616              5690616.0
# 4              1    10.0    58  1:34:50.616              5690616.0
#
#    fastestLap  rank fastestLapTime  max_speed driverRef driver_code  \
# 0        39.0   2.0       1:27.452      218.3  hamilton         HAM
# 1        39.0   2.0       1:27.452      218.3  hamilton         HAM
# 2        39.0   2.0       1:27.452      218.3  hamilton         HAM
# 3        39.0   2.0       1:27.452      218.3  hamilton         HAM
# 4        39.0   2.0       1:27.452      218.3  hamilton         HAM
#
#   nationality                                        url_x  driverStandingsId  \
# 0     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                  1
# 1     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                  9
# 2     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                 27
# 3     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                 48
# 4     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                 69
#
#    raceId_y  points_y  position positionText_y  wins constructorRef     name  \
# 0        18      10.0         1              1     1        mclaren  McLaren
# 1        19      14.0         1              1     1        mclaren  McLaren
# 2        20      14.0         3              3     1        mclaren  McLaren
# 3        21      20.0         2              2     1        mclaren  McLaren
# 4        22      28.0         3              3     1        mclaren  McLaren
#
#   nationality_y                                 url_y    status  \
# 0       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 1       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 2       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 3       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 4       British  http://en.wikipedia.org/wiki/McLaren  Finished
#
#       driver_name   age
# 0  Lewis Hamilton  39.0
# 1  Lewis Hamilton  39.0
# 2  Lewis Hamilton  39.0
# 3  Lewis Hamilton  39.0
# 4  Lewis Hamilton  39.0

# %%
# heatmap

plt.figure(figsize=(17,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
num.remove('dob')
num.remove('statusId')

# %%
# kde plot for checking the normalization 

plt.figure(figsize=(15,50)) 
for i,j in zip(num,range(1,len(num)+1)):
    plt.subplot(11,2,j)
    sns.kdeplot(df[i],shade=True,color='darkblue')
plt.show()

# %%
df.skew()
# Out:
# resultId                 0.383686
# racerId                  0.547478
# driverId                 1.630028
# constructorId            1.274373
# number                   1.356907
# grid                     0.858323
# positionText_x           0.738284
# positionOrder            0.738284
# points                   1.240746
# laps                     0.141507
# timetaken_in_millisec   -0.231371
# fastestLap              -0.284004
# rank                     0.741297
# max_speed                1.070674
# driverStandingsId       -0.201582
# raceId_y                 0.173721
# points_y                 1.700598
# position                 0.569929
# positionText_y           0.569929
# wins                     2.247137
# age                     -0.640899
# dtype: float64

# %% [markdown]
# Still some columns are skewed even after outlier removal and skewness can be normalized during ML part.

# %% [markdown]
# # Encoding
#
# I have choosen LabelEncoding instead of one hot encoding, because one hot will give you a various new columns based on the unique value. I will recommend LabelEncoding to use always, since it will replace in a single column for new value.
#
# Note:
#
#     * To represent a unicode string as a string of bytes is known as encoding.
#     * To convert a string of bytes to a unicode string is known as decoding.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# encoding categorical columns

for i in cat:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid  positionText_x  \
# 0         1       18         1              1    22.0     1               0
# 1         1       18         1              1    22.0     1               0
# 2         1       18         1              1    22.0     1               0
# 3         1       18         1              1    22.0     1               0
# 4         1       18         1              1    22.0     1               0
#
#    positionOrder  points  laps  time  timetaken_in_millisec  fastestLap  rank  \
# 0              1    10.0    58  1783              5690616.0        39.0   2.0
# 1              1    10.0    58  1783              5690616.0        39.0   2.0
# 2              1    10.0    58  1783              5690616.0        39.0   2.0
# 3              1    10.0    58  1783              5690616.0        39.0   2.0
# 4              1    10.0    58  1783              5690616.0        39.0   2.0
#
#    fastestLapTime  max_speed  driverRef  driver_code  nationality  url_x  \
# 0             601      218.3         20           17            5     36
# 1             601      218.3         20           17            5     36
# 2             601      218.3         20           17            5     36
# 3             601      218.3         20           17            5     36
# 4             601      218.3         20           17            5     36
#
#    driverStandingsId  raceId_y  points_y  position  positionText_y  wins  \
# 0                  1        18      10.0         1               0     1
# 1                  9        19      14.0         1               0     1
# 2                 27        20      14.0         3              17     1
# 3                 48        21      20.0         2              11     1
# 4                 69        22      28.0         3              17     1
#
#    constructorRef  name  nationality_y  url_y  status  driver_name   age
# 0              11    11              1      9       0           36  39.0
# 1              11    11              1      9       0           36  39.0
# 2              11    11              1      9       0           36  39.0
# 3              11    11              1      9       0           36  39.0
# 4              11    11              1      9       0           36  39.0

# %%
x = df.drop('driver_name',1)
y = df.driver_name

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# # ML Algorithms

# %%
# importing ML libraries 

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import tree

# %%
clf = DecisionTreeClassifier(max_depth=5,random_state=1234)
clf.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=1234)

# %%
tree.export_text(clf)
# Out:
# '|--- feature_17 <= 2.50\n|   |--- feature_16 <= 1.50\n|   |   |--- feature_2 <= 500.50\n|   |   |   |--- class: 22\n|   |   |--- feature_2 >  500.50\n|   |   |   |--- class: 1\n|   |--- feature_16 >  1.50\n|   |   |--- class: 18\n|--- feature_17 >  2.50\n|   |--- feature_16 <= 4.50\n|   |   |--- feature_17 <= 3.50\n|   |   |   |--- class: 38\n|   |   |--- feature_17 >  3.50\n|   |   |   |--- class: 57\n|   |--- feature_16 >  4.50\n|   |   |--- feature_17 <= 8.50\n|   |   |   |--- feature_19 <= 42.00\n|   |   |   |   |--- class: 26\n|   |   |   |--- feature_19 >  42.00\n|   |   |   |   |--- feature_16 <= 7.50\n|   |   |   |   |   |--- class: 69\n|   |   |   |   |--- feature_16 >  7.50\n|   |   |   |   |   |--- class: 65\n|   |   |--- feature_17 >  8.50\n|   |   |   |--- feature_2 <= 8.50\n|   |   |   |   |--- feature_2 <= 7.00\n|   |   |   |   |   |--- class: 45\n|   |   |   |   |--- feature_2 >  7.00\n|   |   |   |   |   |--- class: 33\n|   |   |   |--- feature_2 >  8.50\n|   |   |   |   |--- feature_17 <= 9.50\n|   |   |   |   |   |--- class: 13\n|   |   |   |   |--- feature_17 >  9.50\n|   |   |   |   |   |--- class: 16\n'

# %%
fn = list(df.columns)
fn.remove('driver_name')

# %% [markdown]
# # DT workflow

# %%
# plotting decision tree workflow 

fig = plt.figure(figsize=(40,40))
_ = tree.plot_tree(clf,
               feature_names=fn,
               filled=True)

# %% [markdown]
# # Modeling the data

# %%
# classification ML algorithms 

lr = LogisticRegression(solver='sag')
dt = DecisionTreeClassifier()
rn = RandomForestClassifier()
knn = KNeighborsClassifier()
gb = GaussianNB()
sgd = SGDClassifier()

# %%
li = [lr,sgd,knn,gb,rn,dt]
d = {}
for i in li:
    i.fit(xtrain,ytrain)
    ypred = i.predict(xtest)
    print(i,":",accuracy_score(ypred,ytest)*100)
    d.update({str(i):i.score(xtest,ytest)*100})
# Out:
# LogisticRegression(solver='sag') : 16.49622721094812

# %%
plt.figure(figsize=(15, 7.5))
plt.title("Algorithm vs Accuracy", fontweight='bold')
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.plot(d.keys(),d.values(),marker='o',color='plum',linewidth=4,markersize=13,
         markerfacecolor='gold',markeredgecolor='slategray')
for x,y in zip(d.keys(),d.values()):
    label = "{:.2f}".format(y)
    plt.annotate(label,(x,y),textcoords="offset points",xytext=(-3.75,5),ha='right')
plt.show()

# %% [markdown]
# As you can see, the accuracy of basic algorithm (logistic) and SGD is not good as expected. Since the data are skewed/denormalized, so it can be fixed by scaling the data.

# %% [markdown]
# # [MinMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)
#
# Each value in a feature, MinMaxScaler subtracts the minimum value in the feature and then divides by the range. The range is the difference between the original maximum and original minimum. MinMaxScaler preserves the shape of the original distribution.

# %%
from sklearn.preprocessing import MinMaxScaler
# fit scaler on training data
norm = MinMaxScaler().fit(xtrain)
# transform training data
X_train_norm = norm.transform(xtrain)
# transform testing data
X_test_norm = norm.transform(xtest)

# %%
li = [lr,sgd,rn,knn,gb,dt]
di = {}
for i in li:
    i.fit(X_train_norm,ytrain)
    ypred = i.predict(X_test_norm)
    print(i,":",accuracy_score(ypred,ytest)*100)
    di.update({str(i):i.score(X_test_norm,ytest)*100})

# %%
plt.figure(figsize=(15, 7.5))
plt.title("Algorithm vs Accuracy", fontweight='bold')
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.plot(di.keys(),di.values(),marker='o',color='skyblue',linewidth=4,markersize=13,
         markerfacecolor='gold',markeredgecolor='black')
for x,y in zip(di.keys(),di.values()):
    label = "{:.2f}".format(y)
    plt.annotate(label,(x,y),textcoords="offset points",xytext=(-3.75,5),ha='right')
plt.show()

# %% [markdown]
# As you can see the accuracy are getting high for Logistic Regression and SGDClassifier, both the algorithms are performing well from bottom low to 99% accuracy by scaling. Hence this prove the importance of normalizing the data.

# %% [markdown]
# # [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)
#
# StandardScaler removes the mean and scales each feature/variable to unit variance. This operation is performed feature-wise in an independent way. StandardScaler can be influenced by outliers (if they exist in the dataset) since it involves the estimation of the empirical mean and standard deviation of each feature.

# %%
from sklearn.preprocessing import StandardScaler
# fit scaler on training data
std = StandardScaler().fit(xtrain)
# transform train data
x_train_std = std.transform(xtrain)
# transform test data
x_test_std = std.transform(xtest)

# %%
li = [lr,sgd,rn,knn,gb,dt]
dic = {}
for i in li:
    i.fit(x_train_std,ytrain)
    ypred = i.predict(x_test_std)
    print(i,":",accuracy_score(ypred,ytest)*100)
    dic.update({str(i):i.score(x_test_std,ytest)*100})

# %%
plt.figure(figsize=(15, 7.5))
plt.title("Algorithm vs Accuracy", fontweight='bold')
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.plot(dic.keys(),dic.values(),marker='o',color='mediumpurple',linewidth=4,markersize=13,
         markerfacecolor='gold',markeredgecolor='black')
for x,y in zip(dic.keys(),dic.values()):
    label = "{:.2f}".format(y)
    plt.annotate(label,(x,y),textcoords="offset points",xytext=(-3.75,5),ha='right')
plt.show()

# %% [markdown]
# # [RobustScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html)
#
# Scale features using statistics that are robust to outliers. This Scaler removes the median and scales the data according to the quantile range (defaults to IQR: Interquartile Range). The IQR is the range between the 1st quartile (25th quantile) and the 3rd quartile (75th quantile)

# %%
from sklearn.preprocessing import RobustScaler
# fit scaler on train data
scaler = RobustScaler().fit(xtrain)
# transform train data
xtrain_scaled = scaler.transform(xtrain)
# transform test data
xtest_scaled = scaler.transform(xtest)

# %%
li = [lr,sgd,rn,knn,gb,dt]
dics = {}
for i in li:
    i.fit(xtrain_scaled,ytrain)
    ypred = i.predict(xtest_scaled)
    print(i,":",accuracy_score(ypred,ytest)*100)
    dics.update({str(i):i.score(xtest_scaled,ytest)*100})

# %%
plt.figure(figsize=(15, 7.5))
plt.title("Algorithm vs Accuracy", fontweight='bold')
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.plot(dics.keys(),dics.values(),marker='o',color='darkseagreen',linewidth=4,markersize=13,
         markerfacecolor='gold',markeredgecolor='black')
for x,y in zip(dics.keys(),dics.values()):
    label = "{:.2f}".format(y)
    plt.annotate(label,(x,y),textcoords="offset points",xytext=(-3.75,5),ha='right')
plt.show()

# %% [markdown]
# After several stages of scaling process, got a good accuracy score of 100% in all algorithms except SGDClassifier with least of 99% for StandardScaler. Even the least (SGDClassifier) is considered as a very good accuracy.
#
# We made it team, we made it! 🎉
#
# ![podium](https://c.tenor.com/agI-d6PVLeIAAAAC/sebastian-vettel.gif)

# %% [markdown]
# # Thank you!

# %% [markdown]
# If you enjoyed my work give me an upvote, which will really encourage me to work more like this. Do follow me on social meadia, for more coding and explanation of concept in Data Science and Big Data:
# *     linkedin : https://www.linkedin.com/in/anandaram-g/
# *     Kaggle : https://www.kaggle.com/anandaramg
# *     Github : https://github.com/anand-lab-172
# *     Medium : https://medium.com/@anandlab
#
# Don't forget to comment if you enjoyed or you find any mistake in my work 😊
